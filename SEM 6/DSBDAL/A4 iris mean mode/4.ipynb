# %%
# !pip install seaborn
# !pip install pandas
# !pip install matplot
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
df=pd.read_csv('iris.csv',index_col='Id')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data=df

# %%
data["Species"].value_counts()
data.rename(columns={"SepalLengthCm":"slength","SepalWidthCm":"swidth","PetalLengthCm":"plength","PetalWidthCm":"pwidth"},inplace=True)

# %%
sum_data = data["slength"].sum()
mean_data = data["slength"].mean()
median_data = data["slength"].median()
std_deviationdata = data["slength"].std()
print("sepal sum ", sum_data)
print("sepal mean",mean_data)
print("sepal median",median_data)
print("sepal std deviation",std_deviationdata)
# Out:
# sepal sum  876.5
# sepal mean 5.843333333333334
# sepal median 5.8
# sepal std deviation 0.828066127977863

# %%
data.isnull()
# Out:
#      slength  swidth  plength  pwidth  Species
# Id
# 1      False   False    False   False    False
# 2      False   False    False   False    False
# 3      False   False    False   False    False
# 4      False   False    False   False    False
# 5      False   False    False   False    False
# ..       ...     ...      ...     ...      ...
# 146    False   False    False   False    False
# 147    False   False    False   False    False
# 148    False   False    False   False    False
# 149    False   False    False   False    False
# 150    False   False    False   False    False
#
# [150 rows x 5 columns]

# %%
data_satosa=data["Species"]=="Iris-setosa"
print("for setosa")
print(data[data_satosa].describe())
# Out:
# for setosa
#         slength     swidth    plength    pwidth
# count  50.00000  50.000000  50.000000  50.00000
# mean    5.00600   3.418000   1.464000   0.24400
# std     0.35249   0.381024   0.173511   0.10721
# min     4.30000   2.300000   1.000000   0.10000
# 25%     4.80000   3.125000   1.400000   0.20000
# 50%     5.00000   3.400000   1.500000   0.20000
# 75%     5.20000   3.675000   1.575000   0.30000
# max     5.80000   4.400000   1.900000   0.60000

# %%
data_satosa=data["Species"]=="Iris-virginica"
print('for virginica')
print(data[data_satosa].describe())
# Out:
# for virginica
#         slength     swidth    plength    pwidth
# count  50.00000  50.000000  50.000000  50.00000
# mean    6.58800   2.974000   5.552000   2.02600
# std     0.63588   0.322497   0.551895   0.27465
# min     4.90000   2.200000   4.500000   1.40000
# 25%     6.22500   2.800000   5.100000   1.80000
# 50%     6.50000   3.000000   5.550000   2.00000
# 75%     6.90000   3.175000   5.875000   2.30000
# max     7.90000   3.800000   6.900000   2.50000

# %%
print('for versicolor')
data_satosa=data["Species"]=='Iris-versicolor'
print(data[data_satosa].describe())
# Out:
# for versicolor
#          slength     swidth    plength     pwidth
# count  50.000000  50.000000  50.000000  50.000000
# mean    5.936000   2.770000   4.260000   1.326000
# std     0.516171   0.313798   0.469911   0.197753
# min     4.900000   2.000000   3.000000   1.000000
# 25%     5.600000   2.525000   4.000000   1.200000
# 50%     5.900000   2.800000   4.350000   1.300000
# 75%     6.300000   3.000000   4.600000   1.500000
# max     7.000000   3.400000   5.100000   1.800000

# %%
# seaborn: It is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# pandas: It is a powerful data manipulation and analysis library. It provides data structures like DataFrames to store and manipulate structured data.

# matplotlib: It is a plotting library for Python. It provides a wide variety of customizable plots and visualizations.

# pd.read_csv: It is a function from the pandas library used to read data from a CSV file and create a DataFrame.

# index_col: It is a parameter used in pd.read_csv to specify a column as the index of the DataFrame.

# df: It is a variable that represents the DataFrame created from the CSV file.

# value_counts(): It is a pandas function used to count the occurrences of each unique value in a column.

# rename(): It is a pandas function used to rename columns in a DataFrame.

# sum(), mean(), median(), std(): These are descriptive statistical functions used to calculate the sum, mean, median, and standard deviation of a column's values.

# isnull(): It is a pandas function that returns a DataFrame of the same shape as the input indicating whether each element is missing or null.

# data_satosa: It is a variable used to filter the DataFrame based on the 'Species' column to select a specific species (Iris-setosa, Iris-virginica, or Iris-versicolor).

# # Now, here are some questions related to the 
# What is the purpose of the df=pd.read_csv('iris.csv',index_col='Id') code?
# A1: The purpose of this code is to read the data from the 'iris.csv' file and create a pandas DataFrame. The 'index_col' parameter is used to specify the 'Id' column as the index of the DataFrame.

# Q2: How can you check the number of occurrences of each species in the 'Species' column?
# A2: You can use the value_counts() function on the 'Species' column of the DataFrame. It will return the count of each unique value in the column.

# Q3: What does data.rename(columns={"SepalLengthCm":"slength","SepalWidthCm":"swidth","PetalLengthCm":"plength","PetalWidthCm":"pwidth"},inplace=True) do?
# A3: This code renames the specified columns in the DataFrame. It renames the columns 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', and 'PetalWidthCm' to 'slength', 'swidth', 'plength', and 'pwidth', respectively. The inplace=True parameter ensures that the changes are made in-place, modifying the DataFrame directly.

# Q4: How can you calculate the sum, mean, median, and standard deviation of the 'slength' column?
# A4: You can use the following code:

# python
# Copy code
# sum_data = data["slength"].sum()
# mean_data = data["slength"].mean()
# median_data = data["slength"].median()
# std_deviationdata = data["slength"].std()
# Q5: How can you check if there are any missing values in the DataFrame?
# A5: You can use the isnull() function on the DataFrame. It returns a DataFrame of the same shape as the input, indicating whether each element is missing or null.

# Q6: How can you filter the DataFrame to get the statistics for a specific species, such as Iris-setosa?
# A6: You can use boolean indexing to filter the DataFrame based on the 'Species' column. For example:

# python
# Copy code
# data_satosa = data["Species"] == "Iris-setosa"
# print(data[data_satosa].describe())
# Q7: Can you provide the descriptive statistics (mean, min, max, etc.) for the Iris-virginica species?
# A7: Yes, you can filter the DataFrame for the Iris-virginica species and then use the describe() function. Here's an example:

# python
# Copy code
# data_virginica = data["Species"] == "Iris-virginica"
# print(data[data_virginica].describe())
# Q8: How can you access the descriptive statistics for the Iris-versicolor species?
# A8: Similar to the previous question, you can filter the DataFrame for the Iris-versicolor species and use the describe() function. Here's an example:

# python
# Copy code
# data_versicolor = data["Species"] == "Iris-versicolor"
# print(data[data_versicolor].describe())
# If you have any more questions, feel free to ask!
